# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoVogiatzis/medical_data_analysis/blob/main/notebooks/Thyroid_Sick.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+git://github.com/albahnsen/CostSensitiveClassification.git
# Out:
# Collecting git+git://github.com/albahnsen/CostSensitiveClassification.git
#   Cloning git://github.com/albahnsen/CostSensitiveClassification.git to /tmp/pip-req-build-0v9wztcg
#   Running command git clone -q git://github.com/albahnsen/CostSensitiveClassification.git /tmp/pip-req-build-0v9wztcg
# Requirement already satisfied: scikit-learn>=0.15.0b2 in /usr/local/lib/python3.7/dist-packages (from costcla==0.6) (0.22.2.post1)
# Requirement already satisfied: pandas>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from costcla==0.6) (1.1.5)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from costcla==0.6) (1.19.5)
# Collecting pyea>=0.2
#   Downloading https://files.pythonhosted.org/packages/e0/d1/628c0a358b105f4d3a33f46ac31b18f3ff468cd3402c73f3c0e9d02da025/pyea-0.2.tar.gz
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0b2->costcla==0.6) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0b2->costcla==0.6) (1.4.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.14.0->costcla==0.6) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.14.0->costcla==0.6) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.14.0->costcla==0.6) (1.15.0)
# Building wheels for collected packages: costcla, pyea
#   Building wheel for costcla (setup.py) ... done
#   Created wheel for costcla: filename=costcla-0.6-cp37-none-any.whl size=3981319 sha256=57e9cf2605091a743e32cc376b7137c222754ad4ecf8f285080ecfa255e9ced7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2bat2g_4/wheels/88/50/a9/46090896420899de912f048c5d91b30b25d5e32d88a2fc23c6
#   Building wheel for pyea (setup.py) ... done
#   Created wheel for pyea: filename=pyea-0.2-cp37-none-any.whl size=6017 sha256=1928166a0a76f1f7d7b8f587f32dff70f5bd2c68c22fe657281745aab4169001
#   Stored in directory: /root/.cache/pip/wheels/3c/bf/6e/06f8b0ed23cbc1fe956f8b6756535cb36f0b68c2f0f2342178
# Successfully built costcla pyea
# Installing collected packages: pyea, costcla
# Successfully installed costcla-0.6 pyea-0.2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection, metrics
from sklearn.metrics import classification_report
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestClassifier
from costcla.metrics import cost_loss
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
data = pd.read_csv("Thyroid_Sick_fixed.csv")

# %%
print(data.shape)
data.head()
# Out:
# (3772, 30)
#     age sex on thyroxine  ... TBG referral source     Class
# 0  41.0   F            f  ... NaN            SVHC  negative
# 1  23.0   F            f  ... NaN           other  negative
# 2  46.0   M            f  ... NaN           other  negative
# 3  70.0   F            t  ... NaN           other  negative
# 4  70.0   F            f  ... NaN             SVI  negative
#
# [5 rows x 30 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        3771 non-null   float64
#  1   sex                        3622 non-null   object
#  2   on thyroxine               3772 non-null   object
#  3   query on thyroxine         3772 non-null   object
#  4   on antithyroid medication  3772 non-null   object
#  5   sick                       3772 non-null   object
#  6   pregnant                   3772 non-null   object
#  7   thyroid surgery            3772 non-null   object
#  8   I131 treatment             3772 non-null   object
#  9   query hypothyroid          3772 non-null   object
#  10  query hyperthyroid         3772 non-null   object
#  11  lithium                    3772 non-null   object
#  12  goitre                     3772 non-null   object
#  13  tumor                      3772 non-null   object
#  14  hypopituitary              3772 non-null   object
#  15  psych                      3772 non-null   object
#  16  TSH measured               3772 non-null   object
#  17  TSH                        3403 non-null   float64
#  18  T3 measured                3772 non-null   object
#  19  T3                         3003 non-null   float64
#  20  TT4 measured               3772 non-null   object
#  21  TT4                        3541 non-null   float64
#  22  T4U measured               3772 non-null   object
#  23  T4U                        3385 non-null   float64
#  24  FTI measured               3772 non-null   object
#  25  FTI                        3387 non-null   float64
#  26  TBG measured               3772 non-null   object
#  27  TBG                        0 non-null      float64
#  28  referral source            3772 non-null   object
#  29  Class                      3772 non-null   object
# dtypes: float64(7), object(23)
# memory usage: 884.2+ KB

# %%
data.describe()
# Out:
#                age          TSH           T3  ...          T4U          FTI  TBG
# count  3771.000000  3403.000000  3003.000000  ...  3385.000000  3387.000000  0.0
# mean     51.735879     5.086766     2.013500  ...     0.995000   110.469649  NaN
# std      20.084958    24.521470     0.827434  ...     0.195457    33.089698  NaN
# min       1.000000     0.005000     0.050000  ...     0.250000     2.000000  NaN
# 25%      36.000000     0.500000     1.600000  ...     0.880000    93.000000  NaN
# 50%      54.000000     1.400000     2.000000  ...     0.980000   107.000000  NaN
# 75%      67.000000     2.700000     2.400000  ...     1.080000   124.000000  NaN
# max     455.000000   530.000000    10.600000  ...     2.320000   395.000000  NaN
#
# [8 rows x 7 columns]

# %%
data['Class'].value_counts()
# Out:
# negative    3541
# sick         231
# Name: Class, dtype: int64

# %%
sns.countplot(data['Class'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print(data.isnull().sum())
# Out:
# age                             1
# sex                           150
# on thyroxine                    0
# query on thyroxine              0
# on antithyroid medication       0
# sick                            0
# pregnant                        0
# thyroid surgery                 0
# I131 treatment                  0
# query hypothyroid               0
# query hyperthyroid              0
# lithium                         0
# goitre                          0
# tumor                           0
# hypopituitary                   0
# psych                           0
# TSH measured                    0
# TSH                           369
# T3 measured                     0
# T3                            769
# TT4 measured                    0
# TT4                           231
# T4U measured                    0
# T4U                           387
# FTI measured                    0
# FTI                           385
# TBG measured                    0
# TBG                          3772
# referral source                 0
# Class                           0
# dtype: int64

# %%
data.drop(["TBG", "referral source"], axis=1, inplace=True)
data = data.loc[:, ~data.columns.str.endswith("measured")]

# %%
data.dropna(subset=['sex'], inplace=True)

data = data.replace(["f", "t"], [0, 1])
data = data.replace(["F", "M"], [0, 1])
data = data.replace(["Negative", "Sick"], [0, 1])

# %%
print(data.shape)
# Out:
# (3622, 22)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = (20, 15) 
sns.heatmap(data.corr(), annot = True, linewidths=.5)
plt.title('Corelation Between Features', fontsize = 30)
plt.show()

# %%
X = data.drop(columns=['Class'])
y = data['Class']

# %%
X.head()
# Out:
#     age  sex  on thyroxine  query on thyroxine  ...   T3    TT4   T4U    FTI
# 0  41.0    0             0                   0  ...  2.5  125.0  1.14  109.0
# 1  23.0    0             0                   0  ...  2.0  102.0   NaN    NaN
# 2  46.0    1             0                   0  ...  NaN  109.0  0.91  120.0
# 3  70.0    0             1                   0  ...  1.9  175.0   NaN    NaN
# 4  70.0    0             0                   0  ...  1.2   61.0  0.87   70.0
#
# [5 rows x 21 columns]

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, random_state=42)

# %%
imputer = KNNImputer(n_neighbors=5, weights="uniform")
x_train = imputer.fit_transform(x_train)
x_test = imputer.transform(x_test)

# %%
pd.options.plotting.backend = 'matplotlib'
x_train.hist(bins=30, figsize=(20,15))
plt.title('Distribution of features')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-1268636fc907> in <module>()
#       1 pd.options.plotting.backend = 'matplotlib'
# ----> 2 x_train.hist(bins=30, figsize=(20,15))
#       3 plt.title('Distribution of features')
#       4 plt.show()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'hist'

# %%
#0 is negative, 1 is sick
fp = np.full((y_test.shape[0],1), 5)
fn = np.full((y_test.shape[0],1), 1)
tp = np.zeros((y_test.shape[0],1))
tn = np.zeros((y_test.shape[0],1))
cost_matrix = np.hstack((fp, fn, tp, tn))

print(cost_matrix)
# Out:
# [[5. 1. 0. 0.]
#  [5. 1. 0. 0.]
#  [5. 1. 0. 0.]
#  ...
#  [5. 1. 0. 0.]
#  [5. 1. 0. 0.]
#  [5. 1. 0. 0.]]

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=0)

# %%
print("without sampling")
print(Counter(y_train))
#0: 3541, 1: 231

clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

target_names = ['negative', 'sick']
print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test, y_pred).T) # transpose to align with slides
loss = cost_loss(y_test, y_pred, cost_matrix)
print("Loss : %d\n" %loss)
# Out:
# without sampling
# Counter({'negative': 2379, 'sick': 156})
#               precision    recall  f1-score   support
#
#     negative       0.99      0.99      0.99      1018
#         sick       0.85      0.84      0.85        69
#
#     accuracy                           0.98      1087
#    macro avg       0.92      0.92      0.92      1087
# weighted avg       0.98      0.98      0.98      1087
#
# [[1008   11]
#  [  10   58]]
# Loss : 0

# %%
print("with undersampling")
sampler = RandomUnderSampler(sampling_strategy='majority', random_state=1)
X_rs, y_rs = sampler.fit_resample(x_train, y_train)
print(Counter(y_rs))

model = clf.fit(X_rs, y_rs)
y_pred = clf.predict(x_test)

print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test, y_pred).T) # transpose to align with slides
loss = cost_loss(y_test, y_pred, cost_matrix)
print("%d\n" %loss)
# Out:
# with undersampling
# Counter({'negative': 156, 'sick': 156})
#               precision    recall  f1-score   support
#
#     negative       1.00      0.95      0.97      1018
#         sick       0.57      0.99      0.72        69
#
#     accuracy                           0.95      1087
#    macro avg       0.79      0.97      0.85      1087
# weighted avg       0.97      0.95      0.96      1087
#
# [[967   1]
#  [ 51  68]]
# 0
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
print("with oversampling")
sampler = RandomOverSampler(sampling_strategy='minority', random_state=1)
X_rs, y_rs = sampler.fit_resample(x_train, y_train)
print(Counter(y_rs))

model = clf.fit(X_rs, y_rs)
y_pred = clf.predict(x_test)

print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test, y_pred).T) # transpose to align with slides
loss = cost_loss(y_test, y_pred, cost_matrix)
print("Loss : %d\n" %loss)
# Out:
# with oversampling
# Counter({'negative': 2379, 'sick': 2379})
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
#               precision    recall  f1-score   support
#
#     negative       0.99      0.98      0.99      1018
#         sick       0.79      0.91      0.85        69
#
#     accuracy                           0.98      1087
#    macro avg       0.89      0.95      0.92      1087
# weighted avg       0.98      0.98      0.98      1087
#
# [[1001    6]
#  [  17   63]]
# Loss : 0

# %%
print("with combination")
sampler = RandomUnderSampler(sampling_strategy='majority', random_state=1)
X_rs, y_rs = sampler.fit_resample(x_train, y_train)
sampler = RandomOverSampler(sampling_strategy='minority', random_state=1)
X_rs, y_rs = sampler.fit_resample(X_rs, y_rs)
print(Counter(y_rs))

model = clf.fit(X_rs, y_rs)
y_pred = clf.predict(x_test)

print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test, y_pred).T) # transpose to align with slides
loss = cost_loss(y_test, y_pred, cost_matrix)
print("Loss :%d\n" %loss)
# Out:
# with combination
# Counter({'negative': 156, 'sick': 156})
#               precision    recall  f1-score   support
#
#     negative       1.00      0.95      0.97      1018
#         sick       0.57      0.99      0.72        69
#
#     accuracy                           0.95      1087
#    macro avg       0.79      0.97      0.85      1087
# weighted avg       0.97      0.95      0.96      1087
#
# [[967   1]
#  [ 51  68]]
# Loss :0
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)
